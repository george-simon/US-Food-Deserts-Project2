# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine
from sqlalchemy.orm import Session, sessionmaker

# %%
engine = create_engine("postgresql://postgres:bRanch773millisecond!@localhost:5432/food_deserts")

conn = engine.connect()

# %%
data = pd.read_sql("SELECT * FROM nat_stat_table", conn)

# %%
data.to_html(classes=["State","Total 2010 Pop","Food Desert(FD) Pop"
                     ,"Non-Food Desert(NFD) Pop","% FD","% NFD"
                     ,"White More/Less Likely FD","Black More/Less Likely FD"
                     ,"Amer. Ind./AK Nat. More/Less Likely FD"
                     ,"Asian More/Less Likely FD","Nat. HI/Pac. Is. More/Less Likely FD"
                     ,"Multi-Race More/Less Likely FD","Hispanic More/Less Likely FD"
                     ,"White % FD","Black % FD","Amer. Ind./AK Nat. % FD"
                     ,"Asian % FD","Nat. HI/Pac. Is. % FD","Multi-Race % FD"
                     ,"Hispanic % FD","White % NFD","Black % NFD","Amer. Ind./AK Nat. % NFD"
                     ,"Asian % NFD","Nat. HI/Pac. Is. % NFD","Multi-Race % NFD"
                     ,"Hispanic % NFD"])
# Out:
# '<table border="1" class="dataframe State Total 2010 Pop Food Desert(FD) Pop Non-Food Desert(NFD) Pop % FD % NFD White More/Less Likely FD Black More/Less Likely FD Amer. Ind./AK Nat. More/Less Likely FD Asian More/Less Likely FD Nat. HI/Pac. Is. More/Less Likely FD Multi-Race More/Less Likely FD Hispanic More/Less Likely FD White % FD Black % FD Amer. Ind./AK Nat. % FD Asian % FD Nat. HI/Pac. Is. % FD Multi-Race % FD Hispanic % FD White % NFD Black % NFD Amer. Ind./AK Nat. % NFD Asian % NFD Nat. HI/Pac. Is. % NFD Multi-Race % NFD Hispanic % NFD">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>state</th>\n      <th>total_2010_pop</th>\n      <th>food_desert_pop</th>\n      <th>non_food_desert_pop</th>\n      <th>percent_food_desert</th>\n      <th>percent_non_food_desert</th>\n      <th>white_more_less_likely_fd</th>\n      <th>black_more_less_likely_fd</th>\n      <th>amer_ind_ak_native_more_less_likely_fd</th>\n      <th>asian_more_less_likely_fd</th>\n
# ...
